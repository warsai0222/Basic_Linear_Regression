# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# Importing the dataset and Extracting the Independent and Dependent variables
companies = pd.read_csv(r"C:\College\4th year\8th Sem\Workshop\Linear Regression\1000_Companies.csv")
companies.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#Collecting x and y
x=companies["Marketing Spend"].values
y=companies["Profit"].values

# %%
#Mean of x and y 
mean_x= np.mean(x)
mean_y=np.mean(y)

#total number of values
n=len(x)

#using the formula to calculate a and b 
numer=0
denom=0
for i in range(n):
    numer+=(x[i]-mean_x)*(y[i]-mean_y)
    denom+=(x[i]-mean_x)**2

m=numer/denom
c=mean_y - (m* mean_x)

#print coeff
print(m,c)
# Out:
# 0.42958238539304233 22372.45607207653

# %% [markdown]
# profit= 0.4296* Marketing Spend +22372.4560

# %%
#Let's plot it and see grpahically 
max_x=np.max(x)+100
min_x=np.min(x)-100

#plotting  a scatter plot
plt.scatter(x,y)

plt.xlabel("Marketing Spend")
plt.ylabel("Profit")

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Calculating the R2 value 
ss_t=0
ss_r=0

for i in range(n):
    y_pred= m*x[i]+c
    ss_t += (y[i]-mean_y)**2
    ss_r += (y[i]-y_pred)**2
    
r2=1-(ss_r/ss_t)
print(r2)
# Out:
# 0.841384577048961

# %%
# Data Visualisation
# Building the Correlation matrix
sns.heatmap(companies.corr())
# Out:
# <AxesSubplot:>

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
#cannot use Rank 1 matrix in scikit learn
x= x.reshape((n,1))

print(x)


X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
# Out:
# [[471784.1    ]
#  [443898.53   ]
#  [407934.54   ]
#  [383199.62   ]
#  [366168.42   ]
#  [362861.36   ]
#  [127716.82   ]
#  [323876.68   ]
#  [311613.29   ]
#  [304981.62   ]
#  [229160.95   ]
#  [249744.55   ]
#  [249839.44   ]
#  [252664.93   ]
#  [256512.92   ]
#  [261776.23   ]
#  [264346.06   ]
#  [282574.31   ]
#  [294919.57   ]
#  [     0.     ]
#  [298664.47   ]
#  [299737.29   ]
#  [303319.26   ]
#  [304768.73   ]
#  [140574.81   ]
#  [137962.62   ]
#  [134050.07   ]
#  [353183.81   ]
#  [118148.2    ]
#  [107138.38   ]
#  [ 91131.24   ]
#  [ 88218.23   ]
#  [ 46085.25   ]
#  [214634.81   ]
#  [210797.67   ]
#  [205517.64   ]
#  [201126.82   ]
#  [197029.42   ]
#  [185265.1    ]
#  [174999.3    ]
#  [172795.67   ]
#  [164470.71   ]
#  [148001.11   ]
#  [ 35534.17   ]
#  [ 28334.72   ]
#  [  1903.93   ]
#  [297114.46   ]
#  [     0.     ]
#  [     0.     ]
#  [ 45173.06   ]
#  [236937.1317 ]
#  [143589.7191 ]
#  [242316.5853 ]
#  [195132.5255 ]
#  [160862.6275 ]
# ...

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)
y_pred
r2_score= regressor.score(x,y)

print(r2_score)
# Out:
# 0.8413548537164702

# %%
regressor.predict([[471784.1]])
# Out:
# array([224431.1215225])
